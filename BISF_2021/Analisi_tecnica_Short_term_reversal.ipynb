# %% [markdown]
# #### Strategia d'investimento sui componenti dell'indice S&P 100 con back test - Short term reversal
# https://www.youtube.com/watch?v=xpP048vfNrg
#
# Strategia "long only" - Compriamo i titoli andati peggio nel mese precedente e li teniamo per 1 mese. I titoli "perdenti" ("loser stocks") sono identificati come quelli il cui rendimento si colloca nel decile peggiore.
#
# Il backtest consiste nel confrontare la performance di questa strategia negli ultimi 12 anni con quella dell'indice S&P 100

# %%
import pandas as pd
import numpy as np
from datetime import date, datetime
import datetime as dt
from pandas.tseries.offsets import MonthEnd
import pandas_datareader.data as web
import matplotlib.pyplot as plt

# %% [markdown]
# Ci procuriamo i ticker dei 100 titoli del S&P100 su Wikipedia
#
# https://en.wikipedia.org/wiki/S%26P_100

# %%
tickers = pd.read_html('https://en.wikipedia.org/wiki/S%26P_100')[2]

# %%
tickers.head()
# Out:
#   Symbol                 Name                  Sector
# 0   AAPL                Apple  Information Technology
# 1   ABBV               AbbVie             Health Care
# 2    ABT  Abbott Laboratories             Health Care
# 3    ACN            Accenture  Information Technology
# 4   ADBE                Adobe  Information Technology

# %%
tickers = tickers.Symbol

# %% [markdown]
# Scarichiamo i prezzi

# %%
tickers
# Out:
# 0      AAPL
# 1      ABBV
# 2       ABT
# 3       ACN
# 4      ADBE
#        ...
# 96       VZ
# 97      WBA
# 98      WFC
# 99      WMT
# 100     XOM
# Name: Symbol, Length: 101, dtype: object

# %%
tickers.replace('BRK.B', 'BRK-B', inplace=True)

# %%
tickers.head(30)
# Out:
# 0      AAPL
# 1      ABBV
# 2       ABT
# 3       ACN
# 4      ADBE
# 5       AIG
# 6      AMGN
# 7       AMT
# 8      AMZN
# 9      AVGO
# 10      AXP
# 11       BA
# 12      BAC
# 13     BIIB
# 14       BK
# 15     BKNG
# 16      BLK
# 17      BMY
# 18    BRK-B
# 19        C
# 20      CAT
# 21     CHTR
# 22       CL
# 23    CMCSA
# 24      COF
# 25      COP
# 26     COST
# 27      CRM
# 28     CSCO
# 29      CVS
# Name: Symbol, dtype: object

# %%
start_date = '2008-12-31'
end_date = datetime.today()

# %%
df = web.get_data_yahoo(tickers, start_date, end_date)

# %%
df
# Out:
# Attributes   Adj Close                                                  \
# Symbols           AAPL        ABBV         ABT         ACN        ADBE
# Date
# 2008-12-31    2.621168         NaN   18.815722   25.274433   21.290001
# 2009-01-02    2.787007         NaN   18.882696   25.952742   23.020000
# 2009-01-05    2.904630         NaN   18.558353   26.068365   23.129999
# 2009-01-06    2.856721         NaN   17.951960   25.744629   24.219999
# 2009-01-07    2.794993         NaN   17.853251   26.037525   24.230000
# ...                ...         ...         ...         ...         ...
# 2021-12-02  163.759995  116.870003  128.380005  365.299988  671.880005
# 2021-12-03  161.839996  118.849998  130.270004  361.420013  616.530029
# 2021-12-06  165.320007  121.349998  132.470001  362.230011  622.039978
# 2021-12-07  171.179993  121.510002  132.419998  371.339996  649.960022
# 2021-12-08  175.080002  121.870003  132.369995  374.529999  653.099976
# ...              ...       ...
# 2021-08-31  0.042757 -0.038645
# 2021-09-30 -0.058879  0.078870
# 2021-10-31  0.072033  0.096056
# 2021-11-30 -0.058827 -0.059342
# 2021-12-31 -0.024746  0.043616
#
# [157 rows x 101 columns]

# %%
mtl_ret.describe()
# Out:
# Symbols        AAPL        ABBV         ABT         ACN        ADBE  \
# count    157.000000  157.000000  157.000000  157.000000  157.000000
# mean       0.030088    0.012324    0.013941    0.019077    0.024695
# std        0.077913    0.062168    0.053816    0.059685    0.074243
# min       -0.181198   -0.182854   -0.151885   -0.142901   -0.176122
# 25%       -0.016461   -0.001829   -0.015388   -0.021185   -0.032360
# 50%        0.033790    0.000000    0.011735    0.022343    0.029968
# 75%        0.079314    0.040659    0.046288    0.052914    0.064674
# max        0.216569    0.228907    0.171940    0.160929    0.280838
#
# Symbols         AIG        AMGN         AMT        AMZN        AVGO  ...  \
# count    157.000000  157.000000  157.000000  157.000000  157.000000  ...
# mean       0.026260    0.011894    0.016725    0.030613    0.027761  ...
# std        0.255698    0.063485    0.049118    0.083290    0.077622  ...
# min       -0.671875   -0.153768   -0.127315   -0.202192   -0.209673  ...
# 25%       -0.047636   -0.031977   -0.018571   -0.031421   -0.016089  ...
# 50%        0.011998    0.013505    0.011538    0.026182    0.021933  ...
# 75%        0.062102    0.043640    0.047739    0.082075    0.079768  ...
# max        2.449772    0.179993    0.161969    0.272601    0.266855  ...
#
# Symbols         UNH         UNP         UPS         USB           V  \
# count    157.000000  157.000000  157.000000  157.000000  157.000000
# mean       0.021707    0.018785    0.013193    0.009891    0.020094
# std        0.063462    0.064980    0.068502    0.070422    0.058601
# min       -0.306389   -0.137345   -0.229696   -0.406637   -0.195747
# 25%       -0.017629   -0.018391   -0.020515   -0.023047   -0.019178
# 50%        0.024575    0.021261    0.009776    0.018408    0.025545
# 75%        0.062830    0.052273    0.048575    0.044634    0.056500
# max        0.178456    0.231570    0.284044    0.247091    0.168346
#
# Symbols          VZ         WBA         WFC         WMT         XOM
# count    157.000000  157.000000  157.000000  157.000000  157.000000
# mean       0.008066    0.009324    0.009616    0.008875    0.003560
# std        0.047597    0.079462    0.089775    0.049408    0.063868
# min       -0.117070   -0.192985   -0.358888   -0.159472   -0.261858
# 25%       -0.020617   -0.039861   -0.030608   -0.023653   -0.027182
# 50%        0.003712   -0.000219    0.014693    0.008365    0.002857
# 75%        0.041548    0.058952    0.046143    0.040247    0.042920
# max        0.125896    0.260030    0.405197    0.147764    0.233125
#
# [8 rows x 101 columns]

# %%
formation = dt.datetime(2009,3,31)

# %%
formation
# Out:
# datetime.datetime(2009, 3, 31, 0, 0)

# %%
ret_1 = mtl_ret.loc[formation - MonthEnd(1)]

# %%
ret_1
# Out:
# Symbols
# AAPL   -0.009098
# ABBV    0.000000
# ABT    -0.146104
# ACN    -0.075095
# ADBE   -0.135163
#           ...
# VZ     -0.044861
# WBA    -0.125855
# WFC    -0.347822
# WMT     0.044991
# XOM    -0.107712
# Name: 2009-02-28 00:00:00, Length: 101, dtype: float64

# %%
ret_1.name = 'mtl_ret'

# %%
ret_1 = pd.DataFrame(ret_1)

# %%
ret_1
# Out:
#           mtl_ret
# Symbols
# AAPL    -0.009098
# ABBV     0.000000
# ABT     -0.146104
# ACN     -0.075095
# ADBE    -0.135163
# ...           ...
# VZ      -0.044861
# WBA     -0.125855
# WFC     -0.347822
# WMT      0.044991
# XOM     -0.107712
#
# [101 rows x 1 columns]

# %%
ret_1['decile'] = pd.qcut(ret_1.mtl_ret,10,labels=False)

# %%
ret_1
# Out:
#           mtl_ret  decile
# Symbols
# AAPL    -0.009098       7
# ABBV     0.000000       7
# ABT     -0.146104       2
# ACN     -0.075095       5
# ADBE    -0.135163       3
# ...           ...     ...
# VZ      -0.044861       6
# WBA     -0.125855       3
# WFC     -0.347822       0
# WMT      0.044991       9
# XOM     -0.107712       4
#
# [101 rows x 2 columns]

# %%
losers = ret_1[ret_1.decile == 0].index

# %%
losers
# Out:
# Index(['AIG', 'AXP', 'BA', 'BAC', 'C', 'DD', 'GD', 'GE', 'MET', 'UNH', 'WFC'], dtype='object', name='Symbols')

# %%
losret = mtl_ret.loc[formation, mtl_ret.columns.isin(losers)].mean()

# %% [markdown]
# Questo rendimento è il peggiore di tutto il campione. Se andiamo un mese avanti le cose migliorano

# %%
losret
# Out:
# 0.3519540279532276

# %% [markdown]
# Simuliamo la strategia in tutto il periodo

# %%
def reversal(formation):
    ret_1 = mtl_ret.loc[formation - MonthEnd(1)]
    ret_1.name = 'mtl_ret'
    ret_1 = pd.DataFrame(ret_1)
    ret_1['decile'] = pd.qcut(ret_1.mtl_ret, 10, labels=False,duplicates = 'drop')
    losers = ret_1[ret_1.decile == 0].index
    losret = mtl_ret.loc[formation, mtl_ret.columns.isin(losers)].mean()
    return losret

# %%
reversal(formation)
# Out:
# 0.3519540279532276

# %%
returns = []
dates = []

for i in mtl_ret.index[2:]:
    returns.append(reversal(i))
    dates.append(i)

# %%
returns
# Out:
# [-0.2586931904985162,
#  0.3519540279532276,
#  0.04911381998911293,
#  0.055870429539656596,
#  0.03590619772616703,
#  0.06959335280276241,
#  0.12414872835762462,
#  0.05284297220306593,
#  -0.02080132610064059,
#  0.053069593378954165,
#  0.009936450586443967,
#  0.023026706927884798,
#  0.031778356042914124,
#  0.0811600973359159,
#  -0.027089432521654244,
#  -0.07902415149760122,
#  -0.06964266776503548,
#  0.08148017638207732,
#  0.0039980270041511945,
#  0.09124292110005484,
#  0.015071045761239965,
#  0.014910922484042384,
#  0.05148729870145674,
#  0.022745079929545147,
#  0.0043425347143968085,
#  -0.02259536531455041,
#  0.043080410484591235,
#  -0.021203856889089392,
#  -0.0035707666068391626,
#  -0.05167796302227176,
#  -0.07479255972586556,
#  -0.15337440680534248,
#  0.14496319742876038,
#  -0.018601672832426367,
#  -0.01945461182518352,
#  0.12189928889345766,
#  0.06360032461419154,
#  0.0433488326994714,
#          dates   returns
# 0   2009-02-28 -0.258693
# 1   2009-03-31  0.351954
# 2   2009-04-30  0.049114
# 3   2009-05-31  0.055870
# 4   2009-06-30  0.035906
# ..         ...       ...
# 150 2021-08-31  0.001555
# 151 2021-09-30 -0.007431
# 152 2021-10-31  0.052489
# 153 2021-11-30 -0.052797
# 154 2021-12-31  0.045424
#
# [155 rows x 2 columns]

# %%
frame.returns.mean()
# Out:
# 0.01852991304000169

# %% [markdown]
# Confrontiamo la strategia con il rendimento del benchmark

# %%
df2 = web.get_data_yahoo('^OEX', start_date, end_date)['Adj Close']

# %%
df2
# Out:
# Date
# 2008-12-31     431.540009
# 2009-01-02     444.519989
# 2009-01-05     440.829987
# 2009-01-06     442.720001
# 2009-01-07     429.839996
#                  ...
# 2021-12-02    2115.330078
# 2021-12-03    2095.320068
# 2021-12-06    2120.010010
# 2021-12-07    2164.100098
# 2021-12-08    2170.379883
# Name: Adj Close, Length: 3258, dtype: float64

# %%
bench_ret = df2.pct_change().resample('M').agg(lambda x: (x+1).prod() -1)

# %%
bench_ret
# Out:
# Date
# 2008-12-31    0.000000
# 2009-01-31   -0.093294
# 2009-02-28   -0.110075
# 2009-03-31    0.083685
# 2009-04-30    0.075924
#                 ...
# 2021-08-31    0.033513
# 2021-09-30   -0.048899
# 2021-10-31    0.073047
# 2021-11-30   -0.002092
# 2021-12-31    0.024968
# Freq: M, Name: Adj Close, Length: 157, dtype: float64

# %%
frame['S&P100 ret'] = bench_ret[2:].values

# %%
frame
# Out:
#          dates   returns  S&P100 ret
# 0   2009-02-28 -0.258693   -0.110075
# 1   2009-03-31  0.351954    0.083685
# 2   2009-04-30  0.049114    0.075924
# 3   2009-05-31  0.055870    0.053103
# 4   2009-06-30  0.035906    0.004912
# ..         ...       ...         ...
# 150 2021-08-31  0.001555    0.033513
# 151 2021-09-30 -0.007431   -0.048899
# 152 2021-10-31  0.052489    0.073047
# 153 2021-11-30 -0.052797   -0.002092
# 154 2021-12-31  0.045424    0.024968
#
# [155 rows x 3 columns]

# %%
frame.describe()
# Out:
#           returns  S&P100 ret
# count  155.000000  155.000000
# mean     0.018571    0.011944
# std      0.064353    0.040850
# min     -0.257156   -0.110075
# 25%     -0.007402   -0.007912
# 50%      0.020917    0.015854
# 75%      0.049383    0.035500
# max      0.351954    0.126773

# %% [markdown]
# Calcoliamo i rendimenti composti

# %%
stra_adj_ret = frame.returns.mean() - 0.5*(frame.returns.std())**2
stra_adj_ret
# Out:
# 0.01650081004825782

# %%
sp100_adj_ret = frame['S&P100 ret'].mean() - 0.5*(frame['S&P100 ret'].std())**2
sp100_adj_ret
# Out:
# 0.011109997906632875

# %% [markdown]
# Calcoliamo quante volte la strategia batte il benchmark

# %%
ok = frame[frame.returns > frame['S&P100 ret']].shape[0]
ok
# Out:
# 94

# %%
tutti = frame.shape[0]
tutti
# Out:
# 155

# %%
hit_ratio = ok/tutti
hit_ratio
# Out:
# 0.6064516129032258
